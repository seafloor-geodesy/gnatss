# %%
from gnatss.loaders import read_raw_data_files

# %%
# %%time
# inspvaa_df = read_raw_data_files(
#     data_files=["tests/data/2022/NCL1/NCL1_INSPVAA.dat",],
#     data_file_type="INSPVAA"
# )

# %%
# %%time
insstdeva_df = read_raw_data_files(
    data_files=["tests/data/2022/NCL1/NCL1_INSSTDEVA.dat",],
    data_file_type="INSSTDEVA"
)
# Out:
# CPU times: user 9.68 s, sys: 1.24 s, total: 10.9 s
# Wall time: 10.9 s

# %%
insstdeva_df
# Out:
#          Latitude std  Longitude std  Height std  North Velocity std  \
# 0              0.5002         0.4400      0.7283              0.0179
# 1              0.5002         0.4400      0.7283              0.0179
# 2              0.5002         0.4400      0.7283              0.0179
# 3              0.5002         0.4400      0.7283              0.0179
# 4              0.5002         0.4400      0.7283              0.0179
# ...               ...            ...         ...                 ...
# 3866205        0.3748         0.3184      0.7405              0.0172
# 3866206        0.3748         0.3184      0.7405              0.0172
# 3866207        0.3748         0.3184      0.7405              0.0172
# 3866208        0.3748         0.3184      0.7405              0.0172
# 3866209        0.3748         0.3184      0.7405              0.0172
#
#          East Velocity std  Up Velocity std  Roll std  Pitch std  Heading std  \
# ...
